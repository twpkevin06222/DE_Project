# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
from coord_conv import CoordConv
from skimage.transform import rescale, resize

# %% [markdown]
# ## Load Data

# %%
img_list = np.load('test_npy/7-12-17-preprocessed.npy')

print('Image size: ', img_list.shape[1])
# Out:
# Image size:  203

# %% [markdown]
# ## Resize Image

# %%
re_list = []
for i in range(len(img_list)):
    img_re = resize(img_list[i], (200, 200), anti_aliasing=False)
    re_list.append(img_re)
    
re_list = np.asarray(re_list)

IMG_SIZE = re_list.shape[1]
print('New image size: ', IMG_SIZE)
# Out:
# /home/kevinteng/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# New image size:  200

# %%
for img in re_list:
    plt.imshow(np.reshape(img, (IMG_SIZE, IMG_SIZE)), cmap = 'gray')
    plt.show()
    break
    
#     if input()=='exit':
#         break

# %%
print(np.min(re_list[0]))
print(np.max(re_list[0]))
# Out:
# 0.1490782107843141
# 0.7914949264705882

# %%
#plot historgram 
plt.hist(re_list[0].ravel(),50,[0,1])
plt.show()

# %%
#Dimension for network should include the color channel 
re_list = np.expand_dims(re_list, axis = -1)

#Cast data type to float32 for TensorFlow
re_list = re_list.astype('float32')

# %%
BATCH_SIZE = 32
MAX_STEP = 5000
REPEAT = 20
lr = 1e-3

ds_train = tf.data.Dataset.from_tensor_slices(re_list).shuffle(10000).repeat(REPEAT).batch(BATCH_SIZE)

# %%
from tensorflow.keras import Model, Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Reshape, MaxPooling2D, UpSampling2D
from tensorflow.keras.layers import InputLayer, Conv2DTranspose, Activation, BatchNormalization
from tensorflow.keras.layers import Input

def conv_block(x_in, filters, kernel_size, strides, padding, activation, batch_norm = False, max_pool = False):
    x = Conv2D(filters, kernel_size, strides, padding)(x_in)
    if batch_norm:
        x = BatchNormalization()(x)
    x = Activation(activation)(x)
    
    if max_pool:
        assert strides < 2 or strides < (2,2), "Downsampling too fast for strides greater than 2"
        
        x = MaxPooling2D((2, 2), padding)(x)
        
    return x 

def up_block(x_in, up_size, filters, kernel_size, strides, padding, activation, batch_norm = False):
    u = UpSampling2D(up_size)(x_in)
    #by default during upsampling Conv2D does not need maxpooling!
    conv_u = conv_block(u, filters, kernel_size, strides, padding, activation, batch_norm)
    return conv_u

def encoder(input_layer, coordconv = False, dense_out = False):
    if coordconv:
        conv_01 = CoordConv(x_dim = IMG_SIZE, y_dim = IMG_SIZE, with_r = False, filters = 32, 
              kernel_size = 1, padding='same', activation='relu')(input_layer)
    else:
        conv_01 = conv_block(input_layer, filters = 32, kernel_size = 3, strides = 1, 
                             padding = 'same', activation = 'relu', batch_norm = True)
    
    conv_02 = conv_block(conv_01, filters = 48,kernel_size = 3, strides = 2, 
                         padding = 'same', activation = 'relu', batch_norm = True)
    conv_03 = conv_block(conv_02, filters = 64,kernel_size = 3, strides = 2, 
                         padding = 'same', activation = 'relu', batch_norm = True)
    
    if dense_out:
        flat_01 = Flatten()(conv_03)
        dense_01 = Dense(latent_dim)(flat_01)
        
        return dense_01 
    else:
        conv_04 = conv_block(conv_03, filters = 80,kernel_size = 3, strides = 2, 
                         padding = 'same', activation = 'linear')
        return conv_04
    
def decoder(input_latent, dense_out = False):
    if dense_out:
        #assert tf.rank(input_latent) == 2, "Input not from Dense layer!"
        
        dense_02 = Dense(50*50*64, activation = 'relu')(input_latent)
        up_01 = Reshape((50,50,64))(dense_02)
    
    else:
        up_01 = up_block(input_latent, up_size = 2, filters = 64, kernel_size = 3,
                        strides = 1, padding = 'same', activation = 'relu')
        
    up_02 = up_block(up_01, up_size = 2, filters = 48, kernel_size = 3,
                    strides = 1, padding = 'same', activation = 'relu')
    
    up_03 = up_block(up_02, up_size = 2, filters = 32, kernel_size = 3,
                    strides = 1, padding = 'same', activation = 'relu')
    
    output = conv_block(up_03, filters = 1, kernel_size = 3, strides = 1, 
                        padding = 'same', activation = 'sigmoid')
    return output

# %%
#Low level api without using model.fit

latent_dim = 20
input_layer = Input(shape = (200, 200, 1))
input_latent = Input(shape = (latent_dim,))

#build network
encode_net = Model(input_layer, encoder(input_layer, coordconv = True, dense_out = True))
decode_net = Model(input_latent, decoder(input_latent, dense_out = True))

varis = encode_net.trainable_variables + decode_net.trainable_variables

# %% [markdown]
# ----------------------------

# %%
#High level api

latent_dim = 20
input_layer = Input(shape = (200, 200, 1))

encoder_net = encoder(input_layer, coordconv = True, dense_out = True)
decoder_net = decoder(encoder_net, dense_out = True)
Autoencoder = Model(input_layer, decoder_net)

# %%
# Autoencoder.compile(optimizer='adam', loss='MSE')
# Autoencoder.fit(re_list, re_list, epochs=10, batch_size= 32, verbose=1, shuffle=True) #no validation data

# %%
# recon_img = Autoencoder.predict(re_list)

# for i in range(len(recon_img)):
#     plt.imshow(np.reshape(recon_img[i], (200,200)), cmap = 'gray')
#     plt.show()
    
#     if input()=='exit': break
# Out:
# exit

# %% [markdown]
# -------------------------------------------------

# %% [markdown]
# ## Helper Function

# %%
def plot_2(ori_imgs, recon_imgs, figsize = (5, 5)):
    '''
    Plot comparison of one original and one reconstructed image
    '''
    print()
    fig, axes = plt.subplots(1, 2, figsize = figsize)
    fig.subplots_adjust(hspace=0.4, wspace = 0.4, right =0.7)
    
    axes[0].imshow(np.reshape(ori_imgs,[IMG_SIZE, IMG_SIZE]), cmap = 'gray')
    axes[0].set_xlabel('Original Image')
    axes[0].set_xticks([])
    axes[0].set_yticks([])
    
    axes[1].imshow(np.reshape(recon_imgs,[IMG_SIZE, IMG_SIZE]), cmap = 'gray')
    axes[1].set_xlabel('Reconstructed Image')
    axes[1].set_xticks([])
    axes[1].set_yticks([])
    
    plt.tight_layout()
    plt.show()

# %%
#loss function
loss_fn = tf.losses.MeanSquaredError()
#optimizer 
opt = tf.optimizers.Adam()


max_step_num = int((len(re_list)*REPEAT)/BATCH_SIZE)
print('Total number of steps: ',max_step_num)
print()

@tf.function
def train(imgs):
    with tf.GradientTape() as tape:
        encoded = encode_net(imgs)
        decoded = decode_net(encoded) #decoding encoder
        xent = loss_fn(imgs, decoded)
    grads = tape.gradient(xent, varis)
    opt.apply_gradients(zip(grads, varis))
    
    return xent, decoded

ori_list = [] #original image list
de_list = [] #reconstructed image list

for step, (img_batch) in enumerate(ds_train):
    if step > MAX_STEP:
        break
        
    xent, de_img= train(img_batch)
    ori_list.append(img_batch)
    de_list.append(de_img)
    
    if not step % 100:
        print("Step {}, Loss: {}".format(step, xent.numpy()))
        plot_2(img_batch[0], de_img[0], figsize = (10,10))
# Out:
# Total number of steps:  378
#
# Step 0, Loss: 0.0203657615929842
# Step 100, Loss: 0.00010220360854873434
# Step 200, Loss: 8.714129216969013e-05
# Step 300, Loss: 9.351708285976201e-05

# %%
ori_recon = zip(ori_list[max_step_num - 1], de_list[max_step_num - 1])

for i, (ori, recon) in enumerate(ori_recon):
    plot_2(ori, recon, figsize = (10,10))

# %%
encode_net.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 200, 200, 1)]     0
# _________________________________________________________________
# coord_conv (CoordConv)       (None, 200, 200, 32)      128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 100, 100, 48)      13872
# _________________________________________________________________
# batch_normalization_v2 (Batc (None, 100, 100, 48)      192
# _________________________________________________________________
# activation (Activation)      (None, 100, 100, 48)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 64)        27712
# _________________________________________________________________
# batch_normalization_v2_1 (Ba (None, 50, 50, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 50, 50, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 160000)            0
# _________________________________________________________________
# dense (Dense)                (None, 20)                3200020
# =================================================================
# Total params: 3,242,180
# Trainable params: 3,241,956
# Non-trainable params: 224
# _________________________________________________________________

# %%
decode_net.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 20)]              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 160000)            3360000
# _________________________________________________________________
# reshape (Reshape)            (None, 50, 50, 64)        0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 100, 100, 48)      27696
# _________________________________________________________________
# activation_2 (Activation)    (None, 100, 100, 48)      0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 200, 200, 48)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 200, 200, 32)      13856
# _________________________________________________________________
# activation_3 (Activation)    (None, 200, 200, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 200, 200, 1)       289
# _________________________________________________________________
# activation_4 (Activation)    (None, 200, 200, 1)       0
# =================================================================
# Total params: 3,401,841
# Trainable params: 3,401,841
# Non-trainable params: 0
# _________________________________________________________________

# %%
Autoencoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 200, 200, 1)]     0
# _________________________________________________________________
# coord_conv_1 (CoordConv)     (None, 200, 200, 32)      128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 100, 100, 48)      13872
# _________________________________________________________________
# batch_normalization_v2_2 (Ba (None, 100, 100, 48)      192
# _________________________________________________________________
# activation_5 (Activation)    (None, 100, 100, 48)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 50, 50, 64)        27712
# _________________________________________________________________
# batch_normalization_v2_3 (Ba (None, 50, 50, 64)        256
# _________________________________________________________________
# activation_6 (Activation)    (None, 50, 50, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 160000)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                3200020
# _________________________________________________________________
# dense_3 (Dense)              (None, 160000)            3360000
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 50, 50, 64)        0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 100, 100, 48)      27696
# _________________________________________________________________
# activation_7 (Activation)    (None, 100, 100, 48)      0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 200, 200, 48)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 200, 200, 32)      13856
# _________________________________________________________________
# activation_8 (Activation)    (None, 200, 200, 32)      0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 200, 200, 1)       289
# _________________________________________________________________
# activation_9 (Activation)    (None, 200, 200, 1)       0
# =================================================================
# Total params: 6,644,021
# Trainable params: 6,643,797
# Non-trainable params: 224
# _________________________________________________________________
